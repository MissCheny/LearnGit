# %%
import sys
import os
from IPython.display import HTML, display

# 输入module和excel文件路径
module_path = r"D:\Nocturne\学习书籍\日志2025年\5月14日 excel_to_html\excel_to_html.py"
excel_file = r"git表格.xlsx"

# 动态添加模块路径
sys.path.insert(0, os.path.dirname(module_path))

from excel_to_html import excel_to_html_with_style
display(HTML(excel_to_html_with_style(excel_file)))
# Out:
# <style>
# .excel-table {
#   border-collapse: collapse;
#   width: auto;
#   table-layout: auto;
# }
# .align-left { text-align: left; }
# .align-center { text-align: center; }
# .align-right { text-align: right; }
# .wrap-text {
#   white-space: normal !important;
#   word-wrap: break-word !important;
# }
# .excel-table th, .excel-table td {
#   border: 1px solid #000;
#   padding: 8px;
#   white-space: nowrap;
# }
# </style>
# <table class="excel-table">
#   <tr>
#     <th colspan="2" class="align-center wrap-text">类别</th>
#     <th class="align-center">命令</th>
#     <th class="align-center">说明</th>
#     <th class="align-center">参数说明</th>
#   </tr>
#   <tr>
#     <td rowspan="5" colspan="2" class="align-center wrap-text">仓库初始化</td>
#     <td class="align-left"><code>git init</code></td>
#     <td class="align-left">初始化Git仓库</td>
#     <td ></td>
#   </tr>
#   <tr>
#     <td class="align-left"><code>git init -b [branch]</code></td>
#     <td class="align-left">初始化仓库并指定默认分支</td>
# ...
